# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ##  Jamboree has helped thousands of students like you make it to top colleges abroad. Be it GMAT, GRE or SAT we are going to take input from them and have to say them of getting admission in outside university or not

# %% [markdown]
# # features in jamboree
#
# #### Serial No
# #### GRE Scores
# #### TOEFL Scores
# #### University Rating
# #### Statement of Purpose and Letter of Recommendation Strength
# #### Undergraduate GPA
# #### Research Experience
# #### Chance of Admit

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading the dataset

# %%
df=pd.read_csv("Jamboree_Admission.csv")

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.shape
# Out:
# (500, 9)

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %% [markdown]
# ## Dropping the unique value

# %%
df=df.drop(columns=['Serial No.'])

# %%
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000         500.00000
# mean     8.576440    0.560000           0.72174
# std      0.604813    0.496884           0.14114
# min      6.800000    0.000000           0.34000
# 25%      8.127500    0.000000           0.63000
# ...

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
ls_ascat=[]
ls_asnum=[]
for i in df.columns:
    if df[i].nunique()<=10:
        ls_ascat.append(i)
    else:
        ls_asnum.append(i)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
ls_ascat
# Out:
# ['University Rating', 'SOP', 'LOR ', 'Research']

# %%
ls_asnum
# Out:
# ['GRE Score', 'TOEFL Score', 'CGPA', 'Chance of Admit ']

# %% [markdown]
# ## Univarient analysis

# %%
import statsmodels.api as sm

# %%
for i in ls_asnum:
    fig,axes=plt.subplots(1,3,figsize=(12,4))
    sm.qqplot(df[i],line='45',fit=True,ax=axes[0])
    sns.distplot(df[i],bins=10,ax=axes[1])
    sns.boxplot(df[i],ax=axes[2])
# Out:
# C:\Users\SHREST\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SHREST\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for i in ls_ascat:
    fig,axes=plt.subplots(1,1,figsize=(4,4))
    sns.countplot(df[i])
# Out:
# C:\Users\SHREST\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\SHREST\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\SHREST\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# ## Bivariant analysis

# %%
sns.pairplot(df[ls_asnum])

# %%
for i in ls_ascat:
    fig,axes=plt.subplots(1,2,figsize=(8,4))
    sns.barplot(x=df[i],y=df['Chance of Admit '],ax=axes[0])
    sns.boxplot(x=df[i],y=df['Chance of Admit '],ax=axes[1])

# %%
sns.distplot(df[df['Research']==1]['Chance of Admit '],hist=False,color='Red')
sns.distplot(df[df['Research']==0]['Chance of Admit '],hist=False)
# Out:
# C:\Users\SHREST\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SHREST\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Chance of Admit ', ylabel='Density'>

# %%
## we can say that the 80 to 90 % chance of admit is higher for research one

# %%
4, 3, 2, 5, 1
# Out:
# (4, 3, 2, 5, 1)

# %%
sns.distplot(df[df['University Rating']==1]['Chance of Admit '],hist=False,color='Red')
sns.distplot(df[df['University Rating']==2]['Chance of Admit '],hist=False,color='blue')
sns.distplot(df[df['University Rating']==3]['Chance of Admit '],hist=False,color='orange')
sns.distplot(df[df['University Rating']==4]['Chance of Admit '],hist=False,color='yellow')
sns.distplot(df[df['University Rating']==5]['Chance of Admit '],hist=False,color='black')
# Out:
# C:\Users\SHREST\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SHREST\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# university having 4,5 rating have the more chance of admit

# %% [markdown]
# # Multivariant anlysis

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=df.corr(),linewidth=1)
# Out:
# <AxesSubplot:>

# %%
###   here the gre score,chance of admit ,cgpa are highly corellated

# %% [markdown]
# # Outlier Treatment

# %%
cols = ls_asnum # one or more.
Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)
IQR = Q3 - Q1
df = df[~((df[cols] < (Q1 - 1.5 * IQR)) |(df[cols] > (Q3 + 1.5 * IQR))). any(axis=1)]

# %% [markdown]
# ## standardizing the x

# %%
from sklearn.preprocessing import StandardScaler

# %%
y=df['Chance of Admit ']
x=df.drop(columns=['Chance of Admit '])

# %%
scaler = StandardScaler()

# %%
x_scaled = scaler.fit_transform(x)

# %% [markdown]
# # Linear Regression

# %%
#### cross validating the linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
model_lr=LinearRegression()

# %%
scores=cross_val_score(model_lr,x,y,cv=10)

# %%
scores.mean()
# Out:
# 0.8153344091646464

# %%
model_lr.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=model_lr.predict(x)

# %%
error=y_pred-y

# %%
plt.scatter(x=y_pred,y=error)

# %%
## it shows homocedacity and thwere is not auto corelation

# %%
# here i went for non linear by using polynomila regression and done Regularization

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import GridSearchCV

# %%
par={
    'alpha':[0.01,0.05,0.1,0.5,1,5],
}

# %%
degree = 20
poly = PolynomialFeatures(degree)

# %%
x_poly = poly.fit_transform(x)
x_poly_scaled = scaler.fit_transform(x_scaled)

# %%
### using lAsso ,ridge,elasticent regression   (non linear regression)

# %%
lass = Lasso()
lass_sear=GridSearchCV(estimator=lass,param_grid=par,cv=10,verbose=1)

# %%
lass_sear.fit(x,y)
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# GridSearchCV(cv=10, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.05, 0.1, 0.5, 1, 5]}, verbose=1)

# %%
lass_sear.best_estimator_
# Out:
# Lasso(alpha=0.01)

# %%
lass_sear.best_score_
# Out:
# 0.7593389257238

# %%
lass1 = Lasso(alpha=0.01)
scores=cross_val_score(lass1,x,y,cv=10)

# %%
scores.mean()
# Out:
# 0.7593389257238

# %%
ridg = Ridge(alpha=0.01)
scores=cross_val_score(ridg,x,y,cv=10)

# %%
scores.mean()
# Out:
# 0.8153338449957849

# %%
elastic = ElasticNet(alpha = 0.01)
scores=cross_val_score(elastic,x,y,cv=10)

# %%
k=scores
k=k.reshape(10,1)
k.mean()
# Out:
# 0.7965184628593909

# %% [markdown]
# # reduction of columns

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1)
X = pca.fit_transform(x_scaled)

# %%
df1 = pd.DataFrame(X, columns=['X'])
df1['y'] = y

# %%
sns.scatterplot(x=df1['X'],y=df1['y'])
# Out:
# <AxesSubplot:xlabel='X', ylabel='y'>

# %%
from sklearn.linear_model import LinearRegression
model_lr1=LinearRegression()

# %%
model_lr1.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred=model_lr1.predict(X)

# %%
plt.scatter(x=df1['X'],y=df1['y'],color='r')
plt.plot(X,y_pred)

# %%
model_l2=LinearRegression()

# %%
scores=cross_val_score(model_l2,X,y,cv=10)

# %%
scores.mean()
# Out:
# 0.7808790620349159

# %%
### doing modulation of columns by looking the corelation

# %%
k=0.4*df['CGPA']+0.4*df['GRE Score']+0.2*df['TOEFL Score']

# %%
df2=pd.DataFrame(k,columns=['k'])

# %%
for i in df.columns:
    if i!='CGPA' and i!='GRE Score' and i!='TOEFL Score':
        df2[i]=df[i]

# %%
df2.describe()
# Out:
#                 k  University Rating         SOP        LOR     Research  \
# count  498.000000         498.000000  498.000000  498.000000  498.000000
# mean   151.497799           3.118474    3.374498    3.487952    0.562249
# std      5.749538           1.143620    0.991824    0.924654    0.496609
# min    139.024000           1.000000    1.000000    1.000000    0.000000
# 25%    147.657000           2.000000    2.500000    3.000000    0.000000
# 50%    151.176000           3.000000    3.500000    3.500000    1.000000
# 75%    155.577000           4.000000    4.000000    4.000000    1.000000
# max    163.968000           5.000000    5.000000    5.000000    1.000000
#
#        Chance of Admit
# count        498.000000
# mean           0.723273
# std            0.139327
# min            0.360000
# 25%            0.632500
# 50%            0.720000
# 75%            0.820000
# max            0.970000

# %%
scaler1 = StandardScaler()
df2=scaler.fit_transform(df2)

# %%
Y1=df['Chance of Admit ']
X1=df.drop(columns=['Chance of Admit '])

# %%
model_l3=LinearRegression()
scores=cross_val_score(model_l3,X1,Y1,cv=10)

# %%
scores.mean()
# Out:
# 0.8153344091646464

# %%
## here Linear regression has good score so we will choose linear regression model
